# %%
import sys
sys.path.append("../")
import os
import math
import numpy as np
import cv2
import pandas as pd
from scipy import stats
from pedrec.configs.dataset_configs import get_sim_dataset_cfg_default, get_h36m_dataset_cfg_default
from pedrec.datasets.pedrec_dataset import PedRecDataset
from pedrec.configs.pedrec_net_config import PedRecNet50Config
from pedrec.evaluations.validate import get_2d_pose_pck_results, get_3d_pose_results, get_orientation_results
from pedrec.evaluations.eval_np.eval_pose_2d import get_ref_distance_torso, get_normalized_joint_distances
from pedrec.models.constants.skeleton_pedrec import SKELETON_PEDREC_JOINTS, SKELETON_PEDREC, SKELETON_PEDREC_JOINT
from pedrec.models.constants.dataset_constants import DatasetType
from pedrec.visualizers.skeleton_visualizer import draw_skeleton
from pedrec.visualizers.skeleton_3d_visualizer import add_skeleton_3d_to_axes
from pedrec.visualizers.orientation_visualizer import add_orientation_to_axes
from pedrec.visualizers.visualization_helper_3d import draw_grid_3d, draw_origin_3d
from pedrec.models.data_structures import ImageSize
from pedrec.utils.print_helper import get_heading
from pedrec.utils.pedrec_dataset_helper import get_filter_skeleton2d, get_filter_body_orientation, \
    get_filter_skeleton3d, get_filter_bb, get_filter_head_orientation, get_filter_env
from random import randint
import matplotlib.pyplot as plt

# %%
def print_pck_results(gt, pred, title):
  print("####################################################################")
  print(f"############## PCK results: {title} (num samples: {gt.shape[0]})")
  print("####################################################################")
  pose2d_pck = get_2d_pose_pck_results(gt, pred)
  pose2d_pck05_per_joint = pose2d_pck.pck_05
  pose2d_pck2_per_joint = pose2d_pck.pck_2
  pose2d_pck05_mean = pose2d_pck.pck_05_mean
  pose2d_pck2_mean = pose2d_pck.pck_2_mean

  for joint, pck05, pck2 in zip(SKELETON_PEDREC_JOINTS, pose2d_pck05_per_joint, pose2d_pck2_per_joint):
    print(f"{joint.name} | PCK@0.05: {pck05:.2f} | PCK@0.2: {pck2:.2f}")

  print(f"Mean: PCK@0.05: {pose2d_pck05_mean} | PCK@0.2: {pose2d_pck2_mean}")

# %%
def print_pose3d_results(gt, pred, title):
  pose3d_results = get_3d_pose_results(gt, pred)
  print("########################################################")
  print(f"#################### MPJPE: {title}, Num samples: {gt.shape[0]}")
  print("########################################################")

  for joint, mpjpe, x_dist, y_dist, depth_distance in zip(SKELETON_PEDREC_JOINTS, 
                    pose3d_results.mpjpe, 
                    pose3d_results.mean_joint_x_distances,
                    pose3d_results.mean_joint_y_distances,
                    pose3d_results.mean_joint_depth_distances):
    print(f"{joint.name}: MPJPE: {mpjpe:.1f}mm | Depth distance: {depth_distance:.1f}mm | X distance: {x_dist:.1f}mm | Y distance: {y_dist:1f}mm |")
  for limb, correct_depth, correct_pos in zip(SKELETON_PEDREC, pose3d_results.pct_correct_depth_per_pair, pose3d_results.pct_correct_joint_position_per_pair):
    print(f"{SKELETON_PEDREC_JOINT(limb[0]).name}-{SKELETON_PEDREC_JOINT(limb[1]).name}: Correct Relative Position: {correct_pos*100:.2f}%, Correct Relative Depth: {correct_depth*100:.2f}%")
  print(f"Full mean: {pose3d_results.mpjpe_mean:.2f}mm | Correct Depth (Mean) {pose3d_results.pct_correct_depth_mean*100:.2f}% | Correct Joint Position (Mean): {pose3d_results.pct_correct_joint_position_mean*100:.2f}%")

# %%
def print_pose3d_results_latex(gt, pred, title):
  pose3d_results = get_3d_pose_results(gt, pred)
  print("########################################################")
  print(f"#################### MPJPE: {title}, Num samples: {gt.shape[0]}")
  print("########################################################")

  print("Joint & MPJPE & $\delta x$ & $\delta y$ & $\delta z$ \\\\\\midrule")
  for joint, mpjpe, x_dist, y_dist, depth_distance in zip(SKELETON_PEDREC_JOINTS, 
                    pose3d_results.mpjpe, 
                    pose3d_results.mean_joint_x_distances,
                    pose3d_results.mean_joint_y_distances,
                    pose3d_results.mean_joint_depth_distances):
    print(f"{joint.name} & ${mpjpe:.1f}$ & ${x_dist:.1f}$ & ${y_dist:.1f}$ & ${depth_distance:.1f}$ \\\\")
  for limb, correct_depth, correct_pos in zip(SKELETON_PEDREC, pose3d_results.pct_correct_depth_per_pair, pose3d_results.pct_correct_joint_position_per_pair):
    print(f"{SKELETON_PEDREC_JOINT(limb[0]).name}-{SKELETON_PEDREC_JOINT(limb[1]).name}: Correct Relative Position: {correct_pos*100:.2f}%, Correct Relative Depth: {correct_depth*100:.2f}%")
  print(f"Full mean: {pose3d_results.mpjpe_mean:.2f}mm | Correct Depth (Mean) {pose3d_results.pct_correct_depth_mean*100:.2f}% | Correct Joint Position (Mean): {pose3d_results.pct_correct_joint_position_mean*100:.2f}%")

  _, ax = plt.subplots()
  y_pos = np.arange(len(SKELETON_PEDREC_JOINTS))
  ax.bar(pose3d_results.mean_joint_x_distances, SKELETON_PEDREC_JOINTS, color="r")
  ax.set_xticks(y_pos, SKELETON_PEDREC_JOINTS)

# %%
def print_orientation_results(gt, pred, title):
  orientation_results = get_orientation_results(gt, pred)
  print("########################################################")
  print(f"#################### Orientation Results: {title}")
  print("########################################################")
  
  print(f"Body: Dist.Phi: {math.degrees(orientation_results.body.angle_error_phi):.2f}° | Dist.Theta: {math.degrees(orientation_results.body.angle_error_theta):.2f}° | Spherical Distance: {math.degrees(orientation_results.body.spherical_distance):.2f}°")
  print(f"Head: Dist.Phi: {math.degrees(orientation_results.head.angle_error_phi):.2f}° | Dist.Theta: {math.degrees(orientation_results.head.angle_error_theta):.2f}° | Spherical Distance: {math.degrees(orientation_results.head.spherical_distance):.2f}°")

# %%
def get_arrays(df: pd.DataFrame):
    filter_skeleton2d = get_filter_skeleton2d(df)
    filter_skeleton3d = get_filter_skeleton3d(df)
    filter_body_orientation = get_filter_body_orientation(df)
    filter_head_orientation = get_filter_head_orientation(df)


    skeleton2ds = df[filter_skeleton2d].to_numpy(dtype=np.float32).reshape(df.shape[0], len(SKELETON_PEDREC_JOINTS), 5)
    skeleton3ds = df[filter_skeleton3d].to_numpy(dtype=np.float32).reshape(df.shape[0], len(SKELETON_PEDREC_JOINTS), 6)
    body_orientations = df[filter_body_orientation].to_numpy(dtype=np.float32).reshape(df.shape[0], 1, 5)
    head_orientations = df[filter_head_orientation].to_numpy(dtype=np.float32).reshape(df.shape[0], 1, 5)
    all_orientations = np.concatenate((body_orientations, head_orientations), axis=1)
    orientations = np.zeros((df.shape[0], 2, 5), dtype=np.float32)
    print(all_orientations.shape)
    orientations[:, :, :6] = all_orientations
    return skeleton2ds, skeleton3ds, orientations

# %%
def get_gt_arrays(df: pd.DataFrame):
    filter_env = get_filter_env(df)
    filter_bb = get_filter_bb(df)
    filter_skeleton2d = get_filter_skeleton2d(df)
    filter_skeleton3d = get_filter_skeleton3d(df)
    filter_body_orientation = get_filter_body_orientation(df)
    filter_head_orientation = get_filter_head_orientation(df)

    skeleton2ds = df[filter_skeleton2d].to_numpy(dtype=np.float32).reshape(df.shape[0], len(SKELETON_PEDREC_JOINTS), 5)
    skeleton3ds = df[filter_skeleton3d].to_numpy(dtype=np.float32).reshape(df.shape[0], len(SKELETON_PEDREC_JOINTS), 6)
    body_orientations = df[filter_body_orientation].to_numpy(dtype=np.float32).reshape(df.shape[0], 1, 4)
    head_orientations = df[filter_head_orientation].to_numpy(dtype=np.float32).reshape(df.shape[0], 1, 4)
    all_orientations = np.concatenate((body_orientations, head_orientations), axis=1)
    orientations = np.zeros((df.shape[0], 2, 5), dtype=np.float32)
    print(all_orientations.shape)
    orientations[:, :, :4] = all_orientations
    orientations[:, :, 4] = 1
    bbs=df[filter_bb].to_numpy(dtype=np.float32)
    env_positions=df[filter_env].to_numpy(dtype=np.float32)
    return skeleton2ds, skeleton3ds, orientations, bbs, env_positions

# %%
def get_normalized_joint_dists(target, pred):
    gt_array, pred_array, visible_array = target[:, :, 0:2], pred[:, :, 0:2], target[:, :, 3]
    ref_distances = get_ref_distance_torso(gt_array)

    normalized_joint_distances = get_normalized_joint_distances(gt_array, pred_array, visible_array, ref_distances)
    #     gt_array = gt_array.copy()[ref_distances != 0]
    # pred_array = pred_array.copy()[ref_distances != 0]
    # visible_array = visible_array.copy()[ref_distances != 0]
    # ref_distances = ref_distances[ref_distances != 0]
    return normalized_joint_distances, ref_distances

# %%
df_results = pd.read_pickle("data/datasets/Conti01/results/C01_pred_df_experiment_pedrec_p2d3d_c_o_h36m_sim_mebow_0.pkl")
df = pd.read_pickle("data/datasets/Conti01/rt_conti_01_val.pkl")

print(len(df_results))
print(len(df))
# Out:
# 119257
# 119257

# %%
pd.options.display.max_columns = None
pd.options.display.float_format= '{:.2f}'.format
df.head()
# Out:
#    dataset dataset_type scene_id scene_start scene_end  frame_nr_global  \
# 0  Conti01            1        0           0       179                1
# 1  Conti01            1        0           0       179                2
# 2  Conti01            1        0           0       179                3
# 3  Conti01            1        0           0       179                4
# 4  Conti01            1        0           0       179                5
#
#    frame_nr_local             img_dir  img_id img_type  \
# 0               0  Conti01_10/Right10       1      jpg
# 1               1  Conti01_10/Right10       2      jpg
# 2               2  Conti01_10/Right10       3      jpg
# 3               3  Conti01_10/Right10       4      jpg
# 4               4  Conti01_10/Right10       5      jpg
#
#                              subject_id gender skin_color size bmi age  \
# 0  a780b53f-6cbf-4131-9005-ba245d52c811      1          0    1   1   2
# 1  a780b53f-6cbf-4131-9005-ba245d52c811      1          0    1   1   2
# 2  a780b53f-6cbf-4131-9005-ba245d52c811      1          0    1   1   2
# 3  a780b53f-6cbf-4131-9005-ba245d52c811      1          0    1   1   2
# 4  a780b53f-6cbf-4131-9005-ba245d52c811      1          0    1   1   2
#
#   movement movement_speed  is_real_img actions  bb_center_x  bb_center_y  \
# 0        1              2        False     [1]      1381.20       572.14
# 1        1              2        False     [1]      1383.84       571.36
# 2        1              2        False     [1]      1382.89       571.44
# 3        1              2        False     [1]      1381.53       571.53
# 4        1              2        False     [1]      1379.80       571.61
#
#    bb_width  bb_height  bb_score bb_class  env_position_x  env_position_y  \
# 0     78.39     272.92      1.00     0.00         2856.00        -1061.80
# 1     70.79     271.10      1.00     0.00         2855.27        -1061.80
# 2     70.69     270.96      1.00     0.00         2853.79        -1061.80
# 3     70.86     270.58      1.00     0.00         2851.49        -1061.80
# 4     71.11     269.86      1.00     0.00         2848.28        -1061.80
#
#    env_position_z  body_orientation_theta  body_orientation_phi  \
# 0         9170.00                    0.50                  0.25
# 1         9184.02                    0.50                  0.25
# 2         9199.12                    0.50                  0.25
# 3         9215.31                    0.50                  0.25
# 4         9232.56                    0.50                  0.26
#
#    body_orientation_score body_orientation_visible  head_orientation_theta  \
# 0                    1.00                     1.00                    0.52
# 1                    1.00                     1.00                    0.52
# 2                    1.00                     1.00                    0.52
# 3                    1.00                     1.00                    0.52
# 4                    1.00                     1.00                    0.52
#
#    head_orientation_phi  head_orientation_score head_orientation_visible  \
# 0                  0.26                    1.00                     1.00
# 1                  0.26                    1.00                     1.00
# 2                  0.26                    1.00                     1.00
# 3                  0.26                    1.00                     1.00
# 4                  0.26                    1.00                     1.00
#
#    skeleton2d_nose_x  skeleton2d_nose_y  skeleton2d_nose_score  \
# 0            1387.96             470.30                   1.00
# 1            1387.20             470.39                   1.00
# 2            1386.19             470.54                   1.00
# 3            1384.90             470.80                   1.00
# 4            1383.33             471.15                   1.00
#
#   skeleton2d_nose_visible skeleton2d_nose_supported  skeleton2d_left_eye_x  \
# 0                    1.00                      1.00                1386.34
# 1                    1.00                      1.00                1385.65
# 2                    1.00                      1.00                1384.69
# 3                    1.00                      1.00                1383.46
# 4                    1.00                      1.00                1381.92
#
#    skeleton2d_left_eye_y  skeleton2d_left_eye_score  \
# 0                 464.89                       1.00
# 1                 464.94                       1.00
# 2                 465.08                       1.00
# 3                 465.33                       1.00
# 4                 465.69                       1.00
#
#   skeleton2d_left_eye_visible skeleton2d_left_eye_supported  \
# 0                        1.00                          1.00
# 1                        1.00                          1.00
# 2                        1.00                          1.00
# 3                        1.00                          1.00
# 4                        1.00                          1.00
#
#    skeleton2d_right_eye_x  skeleton2d_right_eye_y  skeleton2d_right_eye_score  \
# 0                 1394.62                  465.42                        1.00
# 1                 1393.89                  465.51                        1.00
# 2                 1392.90                  465.66                        1.00
# 3                 1391.62                  465.93                        1.00
# 4                 1390.06                  466.29                        1.00
#
#   skeleton2d_right_eye_visible skeleton2d_right_eye_supported  \
# 0                         1.00                           1.00
# 1                         1.00                           1.00
# 2                         1.00                           1.00
# 3                         1.00                           1.00
# 4                         1.00                           1.00
#
#    skeleton2d_left_ear_x  skeleton2d_left_ear_y  skeleton2d_left_ear_score  \
# 0                1383.52                 464.76                       1.00
# 1                1382.91                 464.76                       1.00
# 2                1382.02                 464.86                       1.00
# 3                1380.86                 465.07                       1.00
# 4                1379.36                 465.43                       1.00
#
#   skeleton2d_left_ear_visible skeleton2d_left_ear_supported  \
# 0                        1.00                          1.00
# 1                        1.00                          1.00
# 2                        1.00                          1.00
# 3                        1.00                          1.00
# 4                        1.00                          1.00
#
#    skeleton2d_right_ear_x  skeleton2d_right_ear_y  skeleton2d_right_ear_score  \
# 0                 1403.54                  465.66                        1.00
# 1                 1402.84                  465.73                        1.00
# 2                 1401.86                  465.87                        1.00
# 3                 1400.61                  466.12                        1.00
# 4                 1399.04                  466.49                        1.00
#
#   skeleton2d_right_ear_visible skeleton2d_right_ear_supported  \
# 0                         1.00                           1.00
# 1                         1.00                           1.00
# 2                         1.00                           1.00
# 3                         1.00                           1.00
# 4                         1.00                           1.00
#
#    skeleton2d_left_shoulder_x  skeleton2d_left_shoulder_y  \
# 0                     1372.57                      491.02
# 1                     1372.02                      490.86
# 2                     1371.21                      490.84
# 3                     1370.17                      490.93
# 4                     1368.80                      491.22
#
#    skeleton2d_left_shoulder_score skeleton2d_left_shoulder_visible  \
# 0                            1.00                             1.00
# 1                            1.00                             1.00
# 2                            1.00                             1.00
# 3                            1.00                             1.00
# 4                            1.00                             1.00
#
#   skeleton2d_left_shoulder_supported  skeleton2d_right_shoulder_x  \
# 0                               1.00                      1416.76
# 1                               1.00                      1416.02
# 2                               1.00                      1415.02
# 3                               1.00                      1413.74
# 4                               1.00                      1412.12
#
#    skeleton2d_right_shoulder_y  skeleton2d_right_shoulder_score  \
# 0                       494.69                             1.00
# 1                       494.74                             1.00
# 2                       494.81                             1.00
# 3                       494.98                             1.00
# 4                       495.17                             1.00
#
#   skeleton2d_right_shoulder_visible skeleton2d_right_shoulder_supported  \
# 0                              1.00                                1.00
# 1                              1.00                                1.00
# 2                              1.00                                1.00
# 3                              1.00                                1.00
# 4                              1.00                                1.00
#
#    skeleton2d_left_elbow_x  skeleton2d_left_elbow_y  \
# 0                  1356.94                   532.17
# 1                  1356.20                   531.88
# 2                  1355.15                   531.68
# 3                  1353.89                   531.63
# 4                  1352.42                   531.82
#
#    skeleton2d_left_elbow_score skeleton2d_left_elbow_visible  \
# 0                         1.00                          1.00
# 1                         1.00                          1.00
# 2                         1.00                          1.00
# 3                         1.00                          1.00
# 4                         1.00                          1.00
#
#   skeleton2d_left_elbow_supported  skeleton2d_right_elbow_x  \
# 0                            1.00                   1416.83
# 1                            1.00                   1415.77
# 2                            1.00                   1414.59
# 3                            1.00                   1413.05
# 4                            1.00                   1411.38
#
#    skeleton2d_right_elbow_y  skeleton2d_right_elbow_score  \
# 0                    535.44                          1.00
# 1                    535.45                          1.00
# 2                    535.42                          1.00
# 3                    535.54                          1.00
# 4                    535.67                          1.00
#
#   skeleton2d_right_elbow_visible skeleton2d_right_elbow_supported  \
# 0                           1.00                             1.00
# 1                           1.00                             1.00
# 2                           1.00                             1.00
# 3                           1.00                             1.00
# 4                           1.00                             1.00
#
#    skeleton2d_left_wrist_x  skeleton2d_left_wrist_y  \
# 0                  1345.56                   532.93
# 1                  1354.84                   535.54
# 2                  1353.73                   535.09
# 3                  1352.27                   534.93
# 4                  1350.57                   535.02
#
#    skeleton2d_left_wrist_score skeleton2d_left_wrist_visible  \
# 0                         1.00                          1.00
# 1                         1.00                          1.00
# 2                         1.00                          1.00
# 3                         1.00                          1.00
# 4                         1.00                          1.00
#
#   skeleton2d_left_wrist_supported  skeleton2d_right_wrist_x  \
# 0                            1.00                   1402.58
# 1                            1.00                   1401.22
# 2                            1.00                   1399.80
# 3                            1.00                   1398.01
# 4                            1.00                   1396.15
#
#    skeleton2d_right_wrist_y  skeleton2d_right_wrist_score  \
# 0                    535.47                          1.00
# 1                    535.30                          1.00
# 2                    535.03                          1.00
# 3                    534.98                          1.00
# 4                    534.99                          1.00
#
#   skeleton2d_right_wrist_visible skeleton2d_right_wrist_supported  \
# 0                           1.00                             1.00
# 1                           1.00                             1.00
# 2                           1.00                             1.00
# 3                           1.00                             1.00
# 4                           1.00                             1.00
#
#    skeleton2d_left_hip_x  skeleton2d_left_hip_y  skeleton2d_left_hip_score  \
# 0                1374.15                 571.05                       1.00
# 1                1373.17                 570.79                       1.00
# 2                1372.13                 570.74                       1.00
# 3                1370.99                 570.85                       1.00
# 4                1369.74                 571.13                       1.00
#
#   skeleton2d_left_hip_visible skeleton2d_left_hip_supported  \
# 0                        1.00                          1.00
# 1                        1.00                          1.00
# 2                        1.00                          1.00
# 3                        1.00                          1.00
# 4                        1.00                          1.00
#
#    skeleton2d_right_hip_x  skeleton2d_right_hip_y  skeleton2d_right_hip_score  \
# 0                 1398.89                  572.78                        1.00
# 1                 1397.81                  572.67                        1.00
# 2                 1396.67                  572.58                        1.00
# 3                 1395.46                  572.55                        1.00
# 4                 1394.16                  572.66                        1.00
#
#   skeleton2d_right_hip_visible skeleton2d_right_hip_supported  \
# 0                         1.00                           1.00
# 1                         1.00                           1.00
# 2                         1.00                           1.00
# 3                         1.00                           1.00
# 4                         1.00                           1.00
#
#    skeleton2d_left_knee_x  skeleton2d_left_knee_y  skeleton2d_left_knee_score  \
# 0                 1362.00                  614.85                        1.00
# 1                 1360.97                  613.08                        1.00
# 2                 1361.05                  613.06                        1.00
# 3                 1361.31                  613.56                        1.00
# 4                 1361.59                  614.27                        1.00
#
#   skeleton2d_left_knee_visible skeleton2d_left_knee_supported  \
# 0                         1.00                           1.00
# 1                         1.00                           1.00
# 2                         1.00                           1.00
# 3                         1.00                           1.00
# 4                         1.00                           1.00
#
#    skeleton2d_right_knee_x  skeleton2d_right_knee_y  \
# 0                  1400.28                   624.23
# 1                  1400.92                   624.14
# 2                  1400.05                   624.00
# 3                  1399.25                   623.87
# 4                  1398.44                   623.76
#
#    skeleton2d_right_knee_score skeleton2d_right_knee_visible  \
# 0                         1.00                          1.00
# 1                         1.00                          1.00
# 2                         1.00                          1.00
# 3                         1.00                          1.00
# 4                         1.00                          1.00
#
#   skeleton2d_right_knee_supported  skeleton2d_left_ankle_x  \
# 0                            1.00                  1361.69
# 1                            1.00                  1361.73
# 2                            1.00                  1361.26
# 3                            1.00                  1360.03
# 4                            1.00                  1358.44
#
#    skeleton2d_left_ankle_y  skeleton2d_left_ankle_score  \
# 0                   672.78                         1.00
# 1                   671.35                         1.00
# 2                   671.81                         1.00
# 3                   672.33                         1.00
# 4                   672.76                         1.00
#
#   skeleton2d_left_ankle_visible skeleton2d_left_ankle_supported  \
# 0                          1.00                            1.00
# 1                          1.00                            1.00
# 2                          1.00                            1.00
# 3                          1.00                            1.00
# 4                          1.00                            1.00
#
#    skeleton2d_right_ankle_x  skeleton2d_right_ankle_y  \
# 0                   1397.77                    683.87
# 1                   1397.71                    681.96
# 2                   1397.67                    681.75
# 3                   1397.75                    681.52
# 4                   1397.86                    681.14
#
#    skeleton2d_right_ankle_score skeleton2d_right_ankle_visible  \
# 0                          1.00                           1.00
# 1                          1.00                           1.00
# 2                          1.00                           1.00
# 3                          1.00                           1.00
# 4                          1.00                           1.00
#
#   skeleton2d_right_ankle_supported  skeleton2d_hip_center_x  \
# 0                             1.00                  1386.51
# 1                             1.00                  1385.48
# 2                             1.00                  1384.39
# 3                             1.00                  1383.22
# 4                             1.00                  1381.95
#
#    skeleton2d_hip_center_y  skeleton2d_hip_center_score  \
# 0                   571.91                         1.00
# 1                   571.73                         1.00
# 2                   571.66                         1.00
# 3                   571.70                         1.00
# 4                   571.89                         1.00
#
#   skeleton2d_hip_center_visible skeleton2d_hip_center_supported  \
# 0                          1.00                            1.00
# 1                          1.00                            1.00
# 2                          1.00                            1.00
# 3                          1.00                            1.00
# 4                          1.00                            1.00
#
#    skeleton2d_spine_center_x  skeleton2d_spine_center_y  \
# 0                    1390.25                     532.75
# 1                    1389.43                     532.63
# 2                    1388.40                     532.61
# 3                    1387.15                     532.70
# 4                    1385.69                     532.93
#
#    skeleton2d_spine_center_score skeleton2d_spine_center_visible  \
# 0                           1.00                            1.00
# 1                           1.00                            1.00
# 2                           1.00                            1.00
# 3                           1.00                            1.00
# 4                           1.00                            1.00
#
#   skeleton2d_spine_center_supported  skeleton2d_neck_x  skeleton2d_neck_y  \
# 0                              1.00            1394.00             493.32
# 1                              1.00            1393.34             493.27
# 2                              1.00            1392.43             493.32
# 3                              1.00            1391.24             493.49
# 4                              1.00            1389.72             493.79
#
#    skeleton2d_neck_score skeleton2d_neck_visible skeleton2d_neck_supported  \
# 0                   1.00                    1.00                      1.00
# 1                   1.00                    1.00                      1.00
# 2                   1.00                    1.00                      1.00
# 3                   1.00                    1.00                      1.00
# 4                   1.00                    1.00                      1.00
#
#    skeleton2d_head_lower_x  skeleton2d_head_lower_y  \
# 0                  1393.44                   480.17
# 1                  1392.78                   480.16
# 2                  1391.85                   480.24
# 3                  1390.65                   480.44
# 4                  1389.12                   480.77
#
#    skeleton2d_head_lower_score skeleton2d_head_lower_visible  \
# 0                         1.00                          1.00
# 1                         1.00                          1.00
# 2                         1.00                          1.00
# 3                         1.00                          1.00
# 4                         1.00                          1.00
#
#   skeleton2d_head_lower_supported  skeleton2d_head_upper_x  \
# 0                            1.00                  1395.45
# 1                            1.00                  1394.84
# 2                            1.00                  1393.94
# 3                            1.00                  1392.76
# 4                            1.00                  1391.24
#
#    skeleton2d_head_upper_y  skeleton2d_head_upper_score  \
# 0                   448.09                         1.00
# 1                   448.14                         1.00
# 2                   448.28                         1.00
# 3                   448.54                         1.00
# 4                   448.94                         1.00
#
#   skeleton2d_head_upper_visible skeleton2d_head_upper_supported  \
# 0                          1.00                            1.00
# 1                          1.00                            1.00
# 2                          1.00                            1.00
# 3                          1.00                            1.00
# 4                          1.00                            1.00
#
#    skeleton2d_left_foot_end_x  skeleton2d_left_foot_end_y  \
# 0                     1352.08                      687.29
# 1                     1351.66                      684.43
# 2                     1350.76                      683.40
# 3                     1349.32                      682.79
# 4                     1347.48                      682.13
#
#    skeleton2d_left_foot_end_score skeleton2d_left_foot_end_visible  \
# 0                            1.00                             1.00
# 1                            1.00                             1.00
# 2                            1.00                             1.00
# 3                            1.00                             1.00
# 4                            1.00                             1.00
#
#   skeleton2d_left_foot_end_supported  skeleton2d_right_foot_end_x  \
# 0                               1.00                      1392.74
# 1                               1.00                      1392.85
# 2                               1.00                      1392.89
# 3                               1.00                      1392.97
# 4                               1.00                      1393.05
#
#    skeleton2d_right_foot_end_y  skeleton2d_right_foot_end_score  \
# 0                       696.20                             1.00
# 1                       694.59                             1.00
# 2                       694.61                             1.00
# 3                       694.52                             1.00
# 4                       694.27                             1.00
#
#   skeleton2d_right_foot_end_visible skeleton2d_right_foot_end_supported  \
# 0                              1.00                                1.00
# 1                              1.00                                1.00
# 2                              1.00                                1.00
# 3                              1.00                                1.00
# 4                              1.00                                1.00
#
#    skeleton2d_left_hand_end_x  skeleton2d_left_hand_end_y  \
# 0                     1347.68                      534.18
# 1                     1356.77                      536.77
# 2                     1355.52                      536.27
# 3                     1353.94                      536.05
# 4                     1352.05                      536.06
#
#    skeleton2d_left_hand_end_score skeleton2d_left_hand_end_visible  \
# 0                            1.00                             1.00
# 1                            1.00                             1.00
# 2                            1.00                             1.00
# 3                            1.00                             1.00
# 4                            1.00                             1.00
#
#   skeleton2d_left_hand_end_supported  skeleton2d_right_hand_end_x  \
# 0                               1.00                      1388.89
# 1                               1.00                      1387.46
# 2                               1.00                      1386.00
# 3                               1.00                      1384.13
# 4                               1.00                      1382.24
#
#    skeleton2d_right_hand_end_y  skeleton2d_right_hand_end_score  \
# 0                       535.26                             1.00
# 1                       534.99                             1.00
# 2                       534.61                             1.00
# 3                       534.49                             1.00
# 4                       534.42                             1.00
#
#   skeleton2d_right_hand_end_visible skeleton2d_right_hand_end_supported  \
# 0                              1.00                                1.00
# 1                              1.00                                1.00
# 2                              1.00                                1.00
# 3                              1.00                                1.00
# 4                              1.00                                1.00
#
#    skeleton3d_nose_x  skeleton3d_nose_y  skeleton3d_nose_z  \
# 0              37.58             682.60              89.59
# 1              40.32             681.84              92.67
# 2              41.48             681.44              94.89
# 3              41.17             681.18              96.71
# 4              39.80             681.43              98.95
#
#    skeleton3d_nose_score skeleton3d_nose_visible skeleton3d_nose_supported  \
# 0                   1.00                    1.00                      1.00
# 1                   1.00                    1.00                      1.00
# 2                   1.00                    1.00                      1.00
# 3                   1.00                    1.00                      1.00
# 4                   1.00                    1.00                      1.00
#
#    skeleton3d_left_eye_x  skeleton3d_left_eye_y  skeleton3d_left_eye_z  \
# 0                  13.33                 716.70                  46.49
# 1                  16.51                 716.23                  49.56
# 2                  18.01                 716.00                  51.73
# 3                  18.08                 715.91                  53.47
# 4                  16.91                 716.16                  55.61
#
#    skeleton3d_left_eye_score skeleton3d_left_eye_visible  \
# 0                       1.00                        1.00
# 1                       1.00                        1.00
# 2                       1.00                        1.00
# 3                       1.00                        1.00
# 4                       1.00                        1.00
#
#   skeleton3d_left_eye_supported  skeleton3d_right_eye_x  \
# 0                          1.00                   69.85
# 1                          1.00                   72.98
# 2                          1.00                   74.45
# 3                          1.00                   74.49
# 4                          1.00                   73.30
#
#    skeleton3d_right_eye_y  skeleton3d_right_eye_z  skeleton3d_right_eye_score  \
# 0                  713.28                   49.62                        1.00
# 1                  712.62                   53.11                        1.00
# 2                  712.30                   55.65                        1.00
# 3                  712.10                   57.80                        1.00
# 4                  712.33                   60.18                        1.00
#
#   skeleton3d_right_eye_visible skeleton3d_right_eye_supported  \
# 0                         1.00                           1.00
# 1                         1.00                           1.00
# 2                         1.00                           1.00
# 3                         1.00                           1.00
# 4                         1.00                           1.00
#
#    skeleton3d_left_ear_x  skeleton3d_left_ear_y  skeleton3d_left_ear_z  \
# 0                 -23.47                 714.37                 -11.42
# 1                 -19.85                 714.29                  -8.64
# 2                 -17.96                 714.31                  -6.72
# 3                 -17.46                 714.43                  -5.25
# 4                 -18.36                 714.70                  -3.27
#
#    skeleton3d_left_ear_score skeleton3d_left_ear_visible  \
# 0                       1.00                        1.00
# 1                       1.00                        1.00
# 2                       1.00                        1.00
# 3                       1.00                        1.00
# 4                       1.00                        1.00
#
#   skeleton3d_left_ear_supported  skeleton3d_right_ear_x  \
# 0                          1.00                  112.29
# 1                          1.00                  115.83
# 2                          1.00                  117.65
# 3                          1.00                  118.07
# 4                          1.00                  117.12
#
#    skeleton3d_right_ear_y  skeleton3d_right_ear_z  skeleton3d_right_ear_score  \
# 0                  708.77                   -4.22                        1.00
# 1                  708.26                   -0.42                        1.00
# 2                  708.05                    2.40                        1.00
# 3                  707.91                    4.86                        1.00
# 4                  708.14                    7.44                        1.00
#
#   skeleton3d_right_ear_visible skeleton3d_right_ear_supported  \
# 0                         1.00                           1.00
# 1                         1.00                           1.00
# 2                         1.00                           1.00
# 3                         1.00                           1.00
# 4                         1.00                           1.00
#
#    skeleton3d_left_shoulder_x  skeleton3d_left_shoulder_y  \
# 0                     -115.18                      537.13
# 1                     -111.67                      537.74
# 2                     -109.62                      538.26
# 3                     -108.79                      538.81
# 4                     -109.27                      539.22
#
#    skeleton3d_left_shoulder_z  skeleton3d_left_shoulder_score  \
# 0                      -73.67                            1.00
# 1                      -72.29                            1.00
# 2                      -71.46                            1.00
# 3                      -71.29                            1.00
# 4                      -70.34                            1.00
#
#   skeleton3d_left_shoulder_visible skeleton3d_left_shoulder_supported  \
# 0                             1.00                               1.00
# 1                             1.00                               1.00
# 2                             1.00                               1.00
# 3                             1.00                               1.00
# 4                             1.00                               1.00
#
#    skeleton3d_right_shoulder_x  skeleton3d_right_shoulder_y  \
# 0                       181.70                       513.27
# 1                       185.06                       512.56
# 2                       186.95                       512.44
# 3                       187.55                       512.53
# 4                       186.90                       513.61
#
#    skeleton3d_right_shoulder_z  skeleton3d_right_shoulder_score  \
# 0                       -60.54                             1.00
# 1                       -57.13                             1.00
# 2                       -54.24                             1.00
# 3                       -51.35                             1.00
# 4                       -47.63                             1.00
#
#   skeleton3d_right_shoulder_visible skeleton3d_right_shoulder_supported  \
# 0                              1.00                                1.00
# 1                              1.00                                1.00
# 2                              1.00                                1.00
# 3                              1.00                                1.00
# 4                              1.00                                1.00
#
#    skeleton3d_left_elbow_x  skeleton3d_left_elbow_y  skeleton3d_left_elbow_z  \
# 0                  -194.40                   265.23                    10.02
# 1                  -192.26                   266.33                    11.68
# 2                  -191.86                   267.62                    13.41
# 3                  -192.76                   268.64                    13.35
# 4                  -194.39                   269.14                    13.48
#
#    skeleton3d_left_elbow_score skeleton3d_left_elbow_visible  \
# 0                         1.00                          1.00
# 1                         1.00                          1.00
# 2                         1.00                          1.00
# 3                         1.00                          1.00
# 4                         1.00                          1.00
#
#   skeleton3d_left_elbow_supported  skeleton3d_right_elbow_x  \
# 0                            1.00                    216.36
# 1                            1.00                    217.60
# 2                            1.00                    218.46
# 3                            1.00                    217.23
# 4                            1.00                    215.95
#
#    skeleton3d_right_elbow_y  skeleton3d_right_elbow_z  \
# 0                    243.49                     42.21
# 1                    242.58                     45.77
# 2                    242.65                     49.50
# 3                    242.54                     52.39
# 4                    243.43                     55.80
#
#    skeleton3d_right_elbow_score skeleton3d_right_elbow_visible  \
# 0                          1.00                           1.00
# 1                          1.00                           1.00
# 2                          1.00                           1.00
# 3                          1.00                           1.00
# 4                          1.00                           1.00
#
#   skeleton3d_right_elbow_supported  skeleton3d_left_wrist_x  \
# 0                             1.00                  -203.20
# 1                             1.00                  -134.85
# 2                             1.00                  -134.92
# 3                             1.00                  -137.36
# 4                             1.00                  -140.70
#
#    skeleton3d_left_wrist_y  skeleton3d_left_wrist_z  \
# 0                   261.42                   249.26
# 1                   242.62                   242.91
# 2                   245.55                   244.92
# 3                   247.35                   245.31
# 4                   248.49                   245.90
#
#    skeleton3d_left_wrist_score skeleton3d_left_wrist_visible  \
# 0                         1.00                          1.00
# 1                         1.00                          1.00
# 2                         1.00                          1.00
# 3                         1.00                          1.00
# 4                         1.00                          1.00
#
#   skeleton3d_left_wrist_supported  skeleton3d_right_wrist_x  \
# 0                            1.00                    196.06
# 1                            1.00                    194.74
# 2                            1.00                    193.57
# 3                            1.00                    190.03
# 4                            1.00                    186.92
#
#    skeleton3d_right_wrist_y  skeleton3d_right_wrist_z  \
# 0                    244.06                    275.44
# 1                    244.33                    278.75
# 2                    246.14                    282.25
# 3                    247.16                    284.87
# 4                    248.87                    288.04
#
#    skeleton3d_right_wrist_score skeleton3d_right_wrist_visible  \
# 0                          1.00                           1.00
# 1                          1.00                           1.00
# 2                          1.00                           1.00
# 3                          1.00                           1.00
# 4                          1.00                           1.00
#
#   skeleton3d_right_wrist_supported  skeleton3d_left_hip_x  \
# 0                             1.00                 -81.11
# 1                             1.00                 -81.11
# 2                             1.00                 -81.16
# 3                             1.00                 -81.21
# 4                             1.00                 -81.25
#
#    skeleton3d_left_hip_y  skeleton3d_left_hip_z  skeleton3d_left_hip_score  \
# 0                   5.67                   4.63                       1.00
# 1                   6.17                   3.95                       1.00
# 2                   6.09                   3.12                       1.00
# 3                   5.66                   2.50                       1.00
# 4                   5.08                   2.35                       1.00
#
#   skeleton3d_left_hip_visible skeleton3d_left_hip_supported  \
# 0                        1.00                          1.00
# 1                        1.00                          1.00
# 2                        1.00                          1.00
# 3                        1.00                          1.00
# 4                        1.00                          1.00
#
#    skeleton3d_right_hip_x  skeleton3d_right_hip_y  skeleton3d_right_hip_z  \
# 0                   81.11                   -5.67                   -4.63
# 1                   81.11                   -6.17                   -3.95
# 2                   81.15                   -6.09                   -3.12
# 3                   81.21                   -5.66                   -2.50
# 4                   81.25                   -5.08                   -2.35
#
#    skeleton3d_right_hip_score skeleton3d_right_hip_visible  \
# 0                        1.00                         1.00
# 1                        1.00                         1.00
# 2                        1.00                         1.00
# 3                        1.00                         1.00
# 4                        1.00                         1.00
#
#   skeleton3d_right_hip_supported  skeleton3d_left_knee_x  \
# 0                           1.00                 -119.22
# 1                           1.00                 -114.46
# 2                           1.00                 -106.92
# 3                           1.00                  -98.25
# 4                           1.00                  -88.65
#
#    skeleton3d_left_knee_y  skeleton3d_left_knee_z  skeleton3d_left_knee_score  \
# 0                 -294.77                  151.31                        1.00
# 1                 -285.29                  168.79                        1.00
# 2                 -285.98                  168.69                        1.00
# 3                 -289.44                  166.25                        1.00
# 4                 -293.44                  164.30                        1.00
#
#   skeleton3d_left_knee_visible skeleton3d_left_knee_supported  \
# 0                         1.00                           1.00
# 1                         1.00                           1.00
# 2                         1.00                           1.00
# 3                         1.00                           1.00
# 4                         1.00                           1.00
#
#    skeleton3d_right_knee_x  skeleton3d_right_knee_y  skeleton3d_right_knee_z  \
# 0                    76.56                  -346.14                   -47.66
# 1                    93.94                  -348.46                   -28.78
# 2                    92.49                  -347.93                   -38.19
# 3                    91.88                  -346.69                   -48.49
# 4                    92.12                  -344.72                   -58.37
#
#    skeleton3d_right_knee_score skeleton3d_right_knee_visible  \
# 0                         1.00                          1.00
# 1                         1.00                          1.00
# 2                         1.00                          1.00
# 3                         1.00                          1.00
# 4                         1.00                          1.00
#
#   skeleton3d_right_knee_supported  skeleton3d_left_ankle_x  \
# 0                            1.00                  -152.69
# 1                            1.00                  -135.51
# 2                            1.00                  -120.12
# 3                            1.00                  -110.27
# 4                            1.00                  -104.32
#
#    skeleton3d_left_ankle_y  skeleton3d_left_ankle_z  \
# 0                  -677.28                    44.08
# 1                  -673.20                    79.30
# 2                  -681.55                   118.74
# 3                  -689.44                   154.99
# 4                  -695.09                   184.35
#
#    skeleton3d_left_ankle_score skeleton3d_left_ankle_visible  \
# 0                         1.00                          1.00
# 1                         1.00                          1.00
# 2                         1.00                          1.00
# 3                         1.00                          1.00
# 4                         1.00                          1.00
#
#   skeleton3d_left_ankle_supported  skeleton3d_right_ankle_x  \
# 0                            1.00                     20.88
# 1                            1.00                     23.30
# 2                            1.00                     25.96
# 3                            1.00                     29.51
# 4                            1.00                     33.68
#
#    skeleton3d_right_ankle_y  skeleton3d_right_ankle_z  \
# 0                   -729.23                   -170.08
# 1                   -717.57                   -183.14
# 2                   -716.31                   -197.23
# 3                   -714.13                   -212.75
# 4                   -709.95                   -229.22
#
#    skeleton3d_right_ankle_score skeleton3d_right_ankle_visible  \
# 0                          1.00                           1.00
# 1                          1.00                           1.00
# 2                          1.00                           1.00
# 3                          1.00                           1.00
# 4                          1.00                           1.00
#
#   skeleton3d_right_ankle_supported  skeleton3d_hip_center_x  \
# 0                             1.00                     0.00
# 1                             1.00                     0.00
# 2                             1.00                     0.00
# 3                             1.00                     0.00
# 4                             1.00                     0.00
#
#    skeleton3d_hip_center_y  skeleton3d_hip_center_z  \
# 0                     0.00                     0.00
# 1                     0.00                     0.00
# 2                     0.00                     0.00
# 3                     0.00                     0.00
# 4                     0.00                     0.00
#
#    skeleton3d_hip_center_score skeleton3d_hip_center_visible  \
# 0                         1.00                          1.00
# 1                         1.00                          1.00
# 2                         1.00                          1.00
# 3                         1.00                          1.00
# 4                         1.00                          1.00
#
#   skeleton3d_hip_center_supported  skeleton3d_spine_center_x  \
# 0                            1.00                      16.71
# 1                            1.00                      18.32
# 2                            1.00                      19.17
# 3                            1.00                      18.97
# 4                            1.00                      18.39
#
#    skeleton3d_spine_center_y  skeleton3d_spine_center_z  \
# 0                     261.19                     -26.25
# 1                     261.11                     -25.80
# 2                     261.18                     -24.50
# 3                     261.28                     -23.58
# 4                     261.49                     -21.67
#
#    skeleton3d_spine_center_score skeleton3d_spine_center_visible  \
# 0                           1.00                            1.00
# 1                           1.00                            1.00
# 2                           1.00                            1.00
# 3                           1.00                            1.00
# 4                           1.00                            1.00
#
#   skeleton3d_spine_center_supported  skeleton3d_neck_x  skeleton3d_neck_y  \
# 0                              1.00              35.50             522.86
# 1                              1.00              38.80             522.78
# 2                              1.00              40.61             522.81
# 3                              1.00              41.11             522.89
# 4                              1.00              40.32             523.14
#
#    skeleton3d_neck_z  skeleton3d_neck_score skeleton3d_neck_visible  \
# 0             -45.75                   1.00                    1.00
# 1             -43.48                   1.00                    1.00
# 2             -41.71                   1.00                    1.00
# 3             -40.20                   1.00                    1.00
# 4             -37.97                   1.00                    1.00
#
#   skeleton3d_neck_supported  skeleton3d_head_lower_x  skeleton3d_head_lower_y  \
# 0                      1.00                    39.39                   611.24
# 1                      1.00                    42.80                   611.03
# 2                      1.00                    44.60                   610.99
# 3                      1.00                    45.00                   611.04
# 4                      1.00                    44.10                   611.29
#
#    skeleton3d_head_lower_z  skeleton3d_head_lower_score  \
# 0                   -21.67                         1.00
# 1                   -18.91                         1.00
# 2                   -16.91                         1.00
# 3                   -15.25                         1.00
# 4                   -13.01                         1.00
#
#   skeleton3d_head_lower_visible skeleton3d_head_lower_supported  \
# 0                          1.00                            1.00
# 1                          1.00                            1.00
# 2                          1.00                            1.00
# 3                          1.00                            1.00
# 4                          1.00                            1.00
#
#    skeleton3d_head_upper_x  skeleton3d_head_upper_y  skeleton3d_head_upper_z  \
# 0                    48.83                   823.96                   -34.21
# 1                    52.94                   823.78                   -30.32
# 2                    55.13                   823.77                   -27.55
# 3                    55.97                   823.82                   -25.24
# 4                    55.20                   824.06                   -22.93
#
#    skeleton3d_head_upper_score skeleton3d_head_upper_visible  \
# 0                         1.00                          1.00
# 1                         1.00                          1.00
# 2                         1.00                          1.00
# 3                         1.00                          1.00
# 4                         1.00                          1.00
#
#   skeleton3d_head_upper_supported  skeleton3d_left_foot_end_x  \
# 0                            1.00                     -171.44
# 1                            1.00                     -155.90
# 2                            1.00                     -142.13
# 3                            1.00                     -132.84
# 4                            1.00                     -128.28
#
#    skeleton3d_left_foot_end_y  skeleton3d_left_foot_end_z  \
# 0                     -791.77                      204.08
# 1                     -778.91                      245.58
# 2                     -778.12                      291.29
# 3                     -779.19                      332.73
# 4                     -778.08                      365.47
#
#    skeleton3d_left_foot_end_score skeleton3d_left_foot_end_visible  \
# 0                            1.00                             1.00
# 1                            1.00                             1.00
# 2                            1.00                             1.00
# 3                            1.00                             1.00
# 4                            1.00                             1.00
#
#   skeleton3d_left_foot_end_supported  skeleton3d_right_foot_end_x  \
# 0                               1.00                        41.52
# 1                               1.00                        44.82
# 2                               1.00                        47.80
# 3                               1.00                        51.21
# 4                               1.00                        54.96
#
#    skeleton3d_right_foot_end_y  skeleton3d_right_foot_end_z  \
# 0                      -829.27                        -0.20
# 1                      -819.36                       -13.99
# 2                      -819.50                       -28.60
# 3                      -818.17                       -44.70
# 4                      -814.73                       -62.12
#
#    skeleton3d_right_foot_end_score skeleton3d_right_foot_end_visible  \
# 0                             1.00                              1.00
# 1                             1.00                              1.00
# 2                             1.00                              1.00
# 3                             1.00                              1.00
# 4                             1.00                              1.00
#
#   skeleton3d_right_foot_end_supported  skeleton3d_left_hand_end_x  \
# 0                                1.00                     -152.08
# 1                                1.00                      -84.08
# 2                                1.00                      -85.08
# 3                                1.00                      -88.37
# 4                                1.00                      -93.04
#
#    skeleton3d_left_hand_end_y  skeleton3d_left_hand_end_z  \
# 0                      253.37                      379.01
# 1                      234.48                      372.79
# 2                      237.81                      375.18
# 3                      240.01                      375.92
# 4                      241.68                      377.03
#
#    skeleton3d_left_hand_end_score skeleton3d_left_hand_end_visible  \
# 0                            1.00                             1.00
# 1                            1.00                             1.00
# 2                            1.00                             1.00
# 3                            1.00                             1.00
# 4                            1.00                             1.00
#
#   skeleton3d_left_hand_end_supported  skeleton3d_right_hand_end_x  \
# 0                               1.00                       140.38
# 1                               1.00                       138.18
# 2                               1.00                       136.24
# 3                               1.00                       131.68
# 4                               1.00                       127.86
#
#    skeleton3d_right_hand_end_y  skeleton3d_right_hand_end_z  \
# 0                       245.95                       398.35
# 1                       246.94                       401.25
# 2                       249.52                       404.37
# 3                       251.03                       406.48
# 4                       253.30                       409.29
#
#    skeleton3d_right_hand_end_score skeleton3d_right_hand_end_visible  \
# 0                             1.00                              1.00
# 1                             1.00                              1.00
# 2                             1.00                              1.00
# 3                             1.00                              1.00
# 4                             1.00                              1.00
#
#   skeleton3d_right_hand_end_supported
# 0                                1.00
# 1                                1.00
# 2                                1.00
# 3                                1.00
# 4                                1.00

# %%
env_position_xs = [col for col in df if col == "env_position_x"] 
env_position_ys = [col for col in df if col == "env_position_y"] 
env_position_zs = [col for col in df if col == "env_position_z"] 

df["distance_xz"] = np.sqrt(np.abs(df[env_position_xs].sum(axis=1)**2) + np.abs(df[env_position_zs].sum(axis=1)**2))
df_results["distance_xz"] = df["distance_xz"]
df_results["size"] = df["size"]

# %%
skeleton2ds, skeleton3ds, orientatio, bbs, env_positions = get_gt_arrays(df)
skeleton2ds_pred, skeleton3ds_pred, orientations_pred = get_arrays(df_results)
# Out:
# (119257, 2, 4)
# (119257, 2, 5)

# %%
pck_results = print_pck_results(skeleton2ds, skeleton2ds_pred, "jo")
# Out:
# ####################################################################
# ############## PCK results: jo (num samples: 119257)
# ####################################################################
# nose | PCK@0.05: 80.10 | PCK@0.2: 98.98
# left_eye | PCK@0.05: 84.66 | PCK@0.2: 99.22
# right_eye | PCK@0.05: 82.75 | PCK@0.2: 99.14
# left_ear | PCK@0.05: 78.06 | PCK@0.2: 99.04
# right_ear | PCK@0.05: 73.67 | PCK@0.2: 98.91
# left_shoulder | PCK@0.05: 60.94 | PCK@0.2: 98.55
# right_shoulder | PCK@0.05: 72.45 | PCK@0.2: 98.13
# left_elbow | PCK@0.05: 65.30 | PCK@0.2: 95.40
# right_elbow | PCK@0.05: 58.33 | PCK@0.2: 92.24
# left_wrist | PCK@0.05: 57.88 | PCK@0.2: 88.19
# right_wrist | PCK@0.05: 49.25 | PCK@0.2: 80.82
# left_hip | PCK@0.05: 55.56 | PCK@0.2: 95.92
# right_hip | PCK@0.05: 53.59 | PCK@0.2: 95.82
# left_knee | PCK@0.05: 55.69 | PCK@0.2: 91.92
# right_knee | PCK@0.05: 58.17 | PCK@0.2: 91.73
# left_ankle | PCK@0.05: 53.06 | PCK@0.2: 88.91
# right_ankle | PCK@0.05: 50.74 | PCK@0.2: 88.99
# hip_center | PCK@0.05: 63.97 | PCK@0.2: 96.46
# spine_center | PCK@0.05: 83.84 | PCK@0.2: 98.17
# neck | PCK@0.05: 90.03 | PCK@0.2: 99.16
# head_lower | PCK@0.05: 84.76 | PCK@0.2: 99.29
# head_upper | PCK@0.05: 81.49 | PCK@0.2: 99.27
# left_foot_end | PCK@0.05: 39.06 | PCK@0.2: 87.49
# right_foot_end | PCK@0.05: 39.35 | PCK@0.2: 87.26
# left_hand_end | PCK@0.05: 32.38 | PCK@0.2: 80.91
# right_hand_end | PCK@0.05: 23.83 | PCK@0.2: 73.45
# Mean: PCK@0.05: 62.65051739032452 | PCK@0.2: 93.20672137920673

# %%
import tikzplotlib
def print_pose3d_results_latex(gt, pred, title):
  pose3d_results = get_3d_pose_results(gt, pred)
  print("########################################################")
  print(f"#################### MPJPE: {title}, Num samples: {gt.shape[0]}")
  print("########################################################")

  print("Joint & MPJPE & $\delta x$ & $\delta y$ & $\delta z$ \\\\\\midrule")
  for joint, mpjpe, x_dist, y_dist, depth_distance in zip(SKELETON_PEDREC_JOINTS, 
                    pose3d_results.mpjpe, 
                    pose3d_results.mean_joint_x_distances,
                    pose3d_results.mean_joint_y_distances,
                    pose3d_results.mean_joint_depth_distances):
    print(f"{joint.name} & ${mpjpe:.1f}$ & ${x_dist:.1f}$ & ${y_dist:.1f}$ & ${depth_distance:.1f}$ \\\\")
  for limb, correct_depth, correct_pos in zip(SKELETON_PEDREC, pose3d_results.pct_correct_depth_per_pair, pose3d_results.pct_correct_joint_position_per_pair):
    print(f"{SKELETON_PEDREC_JOINT(limb[0]).name}-{SKELETON_PEDREC_JOINT(limb[1]).name}: Correct Relative Position: {correct_pos*100:.2f}%, Correct Relative Depth: {correct_depth*100:.2f}%")
  print(f"Full mean: {pose3d_results.mpjpe_mean:.2f}mm | Correct Depth (Mean) {pose3d_results.pct_correct_depth_mean*100:.2f}% | Correct Joint Position (Mean): {pose3d_results.pct_correct_joint_position_mean*100:.2f}%")

  names = []
  for joint in SKELETON_PEDREC_JOINTS:
    names.append(joint.name)
  names = [x for _, x in sorted(zip(pose3d_results.mpjpe, names))]
  pose3d_results.mean_joint_x_distances = [x for _, x in sorted(zip(pose3d_results.mpjpe, pose3d_results.mean_joint_x_distances))]
  pose3d_results.mean_joint_y_distances = [x for _, x in sorted(zip(pose3d_results.mpjpe, pose3d_results.mean_joint_y_distances))]
  pose3d_results.mean_joint_depth_distances = [x for _, x in sorted(zip(pose3d_results.mpjpe, pose3d_results.mean_joint_depth_distances))]
  pose3d_results.mpjpe = sorted(pose3d_results.mpjpe)

  plt.figure(figsize=(10, 3), dpi=80)
  plt.xticks(rotation=90)
  # y_pos = np.range()
  bar_width = 0.25
  r1 = np.arange(len(names))
  r2 = [x + bar_width for x in r1]
  r3 = [x + bar_width for x in r2]

  plt.bar(r2, pose3d_results.mpjpe, width=0.75, color="white", edgecolor = 'black', label='MPJPE')
  plt.bar(r1, pose3d_results.mean_joint_x_distances, width=bar_width, color="r", edgecolor = 'black', label='$\Delta x$')
  plt.bar(r2, pose3d_results.mean_joint_y_distances, width=bar_width, color="g", edgecolor = 'black', label='$\Delta y$')
  plt.bar(r3, pose3d_results.mean_joint_depth_distances, width=bar_width, color="b", edgecolor = 'black', label='$\Delta z$')

  plt.xticks([r + bar_width for r in range(len(names))], names)
  plt.legend()
  # ax.bar(names, pose3d_results.mean_joint_y_distances, color="g")
  xmin, xmax, ymin, ymax = plt.axis()
  tikzplotlib.save("/home/dennis/Downloads/sim_c01_val_results_msjpe_barchart.tex", extra_axis_parameters={
    'width=\\textwidth',
    'title={MPJPE and joint distances per joint}',
    'enlarge y limits=0.001',
    'xticklabel style={font=\\footnotesize}',
  })

  # ax.set_xticks(y_pos, )

distances_gt = df["distance_xz"].to_numpy()
print(f"Distances mean: {np.mean(distances_gt)} | min: {np.min(distances_gt)} | max: {np.max(distances_gt)}")
print_pose3d_results_latex(skeleton3ds, skeleton3ds_pred, "Full")
# Out:
# Distances mean: 16199.0087890625 | min: 1690.557861328125 | max: 29863.626953125
# ########################################################
# #################### MPJPE: Full, Num samples: 119257
# ########################################################
# Joint & MPJPE & $\delta x$ & $\delta y$ & $\delta z$ \\\midrule
# nose & $85.0$ & $29.6$ & $32.1$ & $60.1$ \\
# left_eye & $82.9$ & $27.1$ & $31.3$ & $59.3$ \\
# right_eye & $84.0$ & $27.8$ & $31.6$ & $60.1$ \\
# left_ear & $82.3$ & $29.3$ & $27.3$ & $58.5$ \\
# right_ear & $85.6$ & $30.3$ & $28.4$ & $61.1$ \\
# left_shoulder & $91.1$ & $36.1$ & $28.1$ & $63.1$ \\
# right_shoulder & $84.4$ & $35.3$ & $29.0$ & $56.1$ \\
# left_elbow & $100.8$ & $44.1$ & $30.7$ & $68.7$ \\
# right_elbow & $115.3$ & $51.1$ & $39.4$ & $75.3$ \\
# left_wrist & $145.0$ & $61.2$ & $52.4$ & $96.7$ \\
# right_wrist & $182.7$ & $72.7$ & $79.0$ & $114.2$ \\
# left_hip & $25.9$ & $14.0$ & $6.4$ & $15.9$ \\
# right_hip & $26.0$ & $14.5$ & $6.1$ & $15.8$ \\
# left_knee & $105.6$ & $34.1$ & $56.1$ & $59.6$ \\
# right_knee & $94.6$ & $31.2$ & $54.3$ & $47.7$ \\
# left_ankle & $166.6$ & $49.5$ & $84.4$ & $100.6$ \\
# right_ankle & $156.8$ & $45.6$ & $83.4$ & $90.7$ \\
# hip_center & $0.1$ & $0.0$ & $0.0$ & $0.1$ \\
# spine_center & $35.6$ & $12.5$ & $14.5$ & $24.2$ \\
# neck & $66.4$ & $21.6$ & $25.1$ & $47.2$ \\
# head_lower & $74.7$ & $23.4$ & $28.5$ & $53.3$ \\
# head_upper & $90.0$ & $29.9$ & $29.9$ & $65.9$ \\
# left_foot_end & $183.9$ & $60.4$ & $91.1$ & $106.6$ \\
# right_foot_end & $177.3$ & $61.8$ & $88.0$ & $98.5$ \\
# left_hand_end & $185.1$ & $76.3$ & $76.4$ & $118.5$ \\
# right_hand_end & $235.4$ & $89.9$ & $111.5$ & $142.9$ \\
# right_shoulder-right_elbow: Correct Relative Position: 53.90%, Correct Relative Depth: 69.69%
# right_elbow-right_wrist: Correct Relative Position: 50.61%, Correct Relative Depth: 66.44%
# left_shoulder-left_elbow: Correct Relative Position: 57.15%, Correct Relative Depth: 77.17%
# left_elbow-left_wrist: Correct Relative Position: 44.82%, Correct Relative Depth: 60.96%
# right_hip-right_knee: Correct Relative Position: 59.94%, Correct Relative Depth: 69.96%
# right_knee-right_ankle: Correct Relative Position: 50.61%, Correct Relative Depth: 79.12%
# left_hip-left_knee: Correct Relative Position: 62.57%, Correct Relative Depth: 72.03%
# left_knee-left_ankle: Correct Relative Position: 59.55%, Correct Relative Depth: 81.79%
# nose-right_eye: Correct Relative Position: 68.24%, Correct Relative Depth: 76.46%
# right_eye-right_ear: Correct Relative Position: 64.42%, Correct Relative Depth: 73.17%
# nose-left_eye: Correct Relative Position: 50.03%, Correct Relative Depth: 66.83%
# left_eye-left_ear: Correct Relative Position: 62.36%, Correct Relative Depth: 76.90%
# hip_center-left_hip: Correct Relative Position: 61.33%, Correct Relative Depth: 86.00%
# hip_center-right_hip: Correct Relative Position: 53.63%, Correct Relative Depth: 69.54%
# hip_center-spine_center: Correct Relative Position: 57.89%, Correct Relative Depth: 75.09%
# spine_center-neck: Correct Relative Position: 57.49%, Correct Relative Depth: 86.17%
# neck-head_lower: Correct Relative Position: 40.43%, Correct Relative Depth: 79.52%
# head_lower-head_upper: Correct Relative Position: 40.58%, Correct Relative Depth: 78.75%
# neck-left_shoulder: Correct Relative Position: 47.16%, Correct Relative Depth: 77.24%
# neck-right_shoulder: Correct Relative Position: 54.85%, Correct Relative Depth: 82.64%
# head_lower-nose: Correct Relative Position: 62.03%, Correct Relative Depth: 84.40%
# left_ankle-left_foot_end: Correct Relative Position: 42.31%, Correct Relative Depth: 77.49%
# right_ankle-right_foot_end: Correct Relative Position: 59.79%, Correct Relative Depth: 86.92%
# left_wrist-left_hand_end: Correct Relative Position: 59.28%, Correct Relative Depth: 85.48%
# right_wrist-right_hand_end: Correct Relative Position: 52.20%, Correct Relative Depth: 84.88%
# Full mean: 106.28mm | Correct Depth (Mean) 77.09% | Correct Joint Position (Mean): 55.07%

# %%
def get_means(distances, joint_distances, bins: int=350):
  results = []
  step_size = int(math.floor((np.max(distances)-np.min(distances)) / bins))
  steps = []
  for i in range(0, bins * step_size, step_size):
    steps.append(i)
    dists = joint_distances[(distances > i) & (distances <= i+step_size)]
    if len(dists) == 0:
      results.append(0)
      continue
    results.append(np.nanmean(dists))
  return steps, results

joint_distances = np.mean(np.linalg.norm(skeleton3ds-skeleton3ds_pred, axis=-1), axis=1)
print(distances_gt.shape)
print(joint_distances.shape)

# joint_distances, ref_distances = get_normalized_joint_dists(skeleton3ds, skeleton3ds_pred)
# joint_distances_plt = joint_distances.copy()[ref_distances != 0]
# distances_gt_plt = distances_gt.copy()[ref_distances != 0]
# joint_distances_plt = joint_distances_plt[distances_gt_plt <= 35000]
# distances_gt_plt = distances_gt_plt[distances_gt_plt <= 35000]
# joint_distance_means_plt = np.mean(joint_distances_plt, axis=1)
x, y = get_means(distances_gt, joint_distances)
fig = plt.figure()
plt.plot(x, y)
plt.show()
# Out:
# (119257,)
# (119257,)

# %%
sizes = df["size"].to_numpy()
print_pose3d_results(skeleton3ds[sizes == 0], skeleton3ds_pred[sizes == 0], f"[sizes == 1]")
# Out:
# ########################################################
# #################### MPJPE: [sizes == 1], Num samples: 5193
# ########################################################
# nose: MPJPE: 54.7mm | Depth distance: 28.1mm | X distance: 19.9mm | Y distance: 30.255737mm |
# left_eye: MPJPE: 52.3mm | Depth distance: 25.8mm | X distance: 17.5mm | Y distance: 30.516191mm |
# right_eye: MPJPE: 54.1mm | Depth distance: 28.1mm | X distance: 17.6mm | Y distance: 30.513462mm |
# left_ear: MPJPE: 53.9mm | Depth distance: 27.2mm | X distance: 20.6mm | Y distance: 28.178858mm |
# right_ear: MPJPE: 59.2mm | Depth distance: 32.9mm | X distance: 22.9mm | Y distance: 26.054117mm |
# left_shoulder: MPJPE: 60.5mm | Depth distance: 35.5mm | X distance: 29.2mm | Y distance: 20.648119mm |
# right_shoulder: MPJPE: 63.0mm | Depth distance: 36.7mm | X distance: 30.8mm | Y distance: 22.214735mm |
# left_elbow: MPJPE: 72.4mm | Depth distance: 48.2mm | X distance: 36.8mm | Y distance: 17.195534mm |
# right_elbow: MPJPE: 103.4mm | Depth distance: 63.1mm | X distance: 43.9mm | Y distance: 41.655891mm |
# left_wrist: MPJPE: 97.1mm | Depth distance: 63.6mm | X distance: 47.4mm | Y distance: 27.764395mm |
# right_wrist: MPJPE: 168.5mm | Depth distance: 64.6mm | X distance: 42.4mm | Y distance: 122.007477mm |
# left_hip: MPJPE: 20.4mm | Depth distance: 11.5mm | X distance: 11.8mm | Y distance: 5.343445mm |
# right_hip: MPJPE: 20.2mm | Depth distance: 11.2mm | X distance: 11.6mm | Y distance: 5.864582mm |
# left_knee: MPJPE: 74.6mm | Depth distance: 45.5mm | X distance: 26.0mm | Y distance: 33.381413mm |
# right_knee: MPJPE: 72.4mm | Depth distance: 44.5mm | X distance: 23.1mm | Y distance: 33.947594mm |
# left_ankle: MPJPE: 115.3mm | Depth distance: 76.1mm | X distance: 34.9mm | Y distance: 52.382908mm |
# right_ankle: MPJPE: 114.4mm | Depth distance: 75.2mm | X distance: 35.4mm | Y distance: 53.476540mm |
# hip_center: MPJPE: 0.1mm | Depth distance: 0.1mm | X distance: 0.0mm | Y distance: 0.000112mm |
# spine_center: MPJPE: 23.6mm | Depth distance: 13.0mm | X distance: 9.2mm | Y distance: 11.560190mm |
# neck: MPJPE: 42.4mm | Depth distance: 22.8mm | X distance: 15.6mm | Y distance: 20.842049mm |
# head_lower: MPJPE: 48.8mm | Depth distance: 25.2mm | X distance: 17.7mm | Y distance: 26.049696mm |
# head_upper: MPJPE: 58.2mm | Depth distance: 32.4mm | X distance: 20.1mm | Y distance: 28.747877mm |
# left_foot_end: MPJPE: 130.3mm | Depth distance: 81.2mm | X distance: 43.0mm | Y distance: 62.849373mm |
# right_foot_end: MPJPE: 134.6mm | Depth distance: 86.7mm | X distance: 43.5mm | Y distance: 59.948666mm |
# left_hand_end: MPJPE: 124.2mm | Depth distance: 82.0mm | X distance: 55.1mm | Y distance: 43.987667mm |
# right_hand_end: MPJPE: 236.8mm | Depth distance: 90.8mm | X distance: 58.2mm | Y distance: 179.307739mm |
# right_shoulder-right_elbow: Correct Relative Position: 65.09%, Correct Relative Depth: 82.06%
# right_elbow-right_wrist: Correct Relative Position: 50.74%, Correct Relative Depth: 66.27%
# left_shoulder-left_elbow: Correct Relative Position: 48.04%, Correct Relative Depth: 76.70%
# left_elbow-left_wrist: Correct Relative Position: 62.69%, Correct Relative Depth: 78.81%
# right_hip-right_knee: Correct Relative Position: 69.91%, Correct Relative Depth: 84.64%
# right_knee-right_ankle: Correct Relative Position: 29.11%, Correct Relative Depth: 44.90%
# left_hip-left_knee: Correct Relative Position: 58.78%, Correct Relative Depth: 70.50%
# left_knee-left_ankle: Correct Relative Position: 58.03%, Correct Relative Depth: 75.37%
# nose-right_eye: Correct Relative Position: 60.11%, Correct Relative Depth: 75.73%
# right_eye-right_ear: Correct Relative Position: 63.24%, Correct Relative Depth: 81.29%
# nose-left_eye: Correct Relative Position: 41.83%, Correct Relative Depth: 55.77%
# left_eye-left_ear: Correct Relative Position: 64.56%, Correct Relative Depth: 76.47%
# hip_center-left_hip: Correct Relative Position: 59.44%, Correct Relative Depth: 85.98%
# hip_center-right_hip: Correct Relative Position: 51.04%, Correct Relative Depth: 68.74%
# hip_center-spine_center: Correct Relative Position: 55.28%, Correct Relative Depth: 71.56%
# spine_center-neck: Correct Relative Position: 59.78%, Correct Relative Depth: 82.54%
# neck-head_lower: Correct Relative Position: 40.61%, Correct Relative Depth: 83.82%
# head_lower-head_upper: Correct Relative Position: 40.68%, Correct Relative Depth: 82.41%
# neck-left_shoulder: Correct Relative Position: 53.96%, Correct Relative Depth: 80.04%
# neck-right_shoulder: Correct Relative Position: 53.13%, Correct Relative Depth: 76.81%
# head_lower-nose: Correct Relative Position: 64.45%, Correct Relative Depth: 84.20%
# left_ankle-left_foot_end: Correct Relative Position: 40.07%, Correct Relative Depth: 76.59%
# right_ankle-right_foot_end: Correct Relative Position: 60.46%, Correct Relative Depth: 87.43%
# left_wrist-left_hand_end: Correct Relative Position: 58.34%, Correct Relative Depth: 87.38%
# right_wrist-right_hand_end: Correct Relative Position: 52.92%, Correct Relative Depth: 86.72%
# Full mean: 79.05mm | Correct Depth (Mean) 77.09% | Correct Joint Position (Mean): 54.81%

# %%
sizes = df["size"].to_numpy()
print_pose3d_results(skeleton3ds[sizes == 1], skeleton3ds_pred[sizes == 1], f"[sizes == 1]")
# Out:
# ########################################################
# #################### MPJPE: [sizes == 1], Num samples: 41907
# ########################################################
# nose: MPJPE: 82.8mm | Depth distance: 55.5mm | X distance: 29.7mm | Y distance: 33.987774mm |
# left_eye: MPJPE: 80.3mm | Depth distance: 54.3mm | X distance: 27.3mm | Y distance: 32.894638mm |
# right_eye: MPJPE: 80.5mm | Depth distance: 54.8mm | X distance: 27.0mm | Y distance: 33.488949mm |
# left_ear: MPJPE: 79.7mm | Depth distance: 52.8mm | X distance: 30.0mm | Y distance: 29.104570mm |
# right_ear: MPJPE: 80.9mm | Depth distance: 54.4mm | X distance: 30.1mm | Y distance: 29.935263mm |
# left_shoulder: MPJPE: 89.3mm | Depth distance: 59.7mm | X distance: 34.9mm | Y distance: 30.186882mm |
# right_shoulder: MPJPE: 82.2mm | Depth distance: 51.9mm | X distance: 35.2mm | Y distance: 30.852064mm |
# left_elbow: MPJPE: 97.6mm | Depth distance: 63.8mm | X distance: 45.1mm | Y distance: 30.044922mm |
# right_elbow: MPJPE: 109.7mm | Depth distance: 69.3mm | X distance: 49.1mm | Y distance: 40.295197mm |
# left_wrist: MPJPE: 142.1mm | Depth distance: 90.7mm | X distance: 62.4mm | Y distance: 54.097473mm |
# right_wrist: MPJPE: 181.0mm | Depth distance: 115.3mm | X distance: 68.9mm | Y distance: 79.679749mm |
# left_hip: MPJPE: 27.5mm | Depth distance: 16.3mm | X distance: 16.0mm | Y distance: 6.598921mm |
# right_hip: MPJPE: 27.7mm | Depth distance: 16.2mm | X distance: 16.9mm | Y distance: 6.064710mm |
# left_knee: MPJPE: 109.0mm | Depth distance: 60.7mm | X distance: 38.1mm | Y distance: 55.911198mm |
# right_knee: MPJPE: 97.4mm | Depth distance: 48.4mm | X distance: 33.4mm | Y distance: 54.754047mm |
# left_ankle: MPJPE: 169.1mm | Depth distance: 99.1mm | X distance: 53.5mm | Y distance: 85.084000mm |
# right_ankle: MPJPE: 159.7mm | Depth distance: 89.4mm | X distance: 48.8mm | Y distance: 84.151680mm |
# hip_center: MPJPE: 0.1mm | Depth distance: 0.1mm | X distance: 0.0mm | Y distance: 0.000111mm |
# spine_center: MPJPE: 34.3mm | Depth distance: 22.3mm | X distance: 11.9mm | Y distance: 15.428536mm |
# neck: MPJPE: 62.3mm | Depth distance: 42.3mm | X distance: 20.1mm | Y distance: 26.158672mm |
# head_lower: MPJPE: 70.5mm | Depth distance: 47.8mm | X distance: 21.8mm | Y distance: 29.686590mm |
# head_upper: MPJPE: 84.5mm | Depth distance: 58.8mm | X distance: 27.7mm | Y distance: 31.933605mm |
# left_foot_end: MPJPE: 190.4mm | Depth distance: 108.8mm | X distance: 63.1mm | Y distance: 93.849449mm |
# right_foot_end: MPJPE: 181.4mm | Depth distance: 97.9mm | X distance: 63.7mm | Y distance: 91.298477mm |
# left_hand_end: MPJPE: 179.9mm | Depth distance: 111.2mm | X distance: 77.5mm | Y distance: 76.055641mm |
# right_hand_end: MPJPE: 235.7mm | Depth distance: 152.4mm | X distance: 83.3mm | Y distance: 107.694748mm |
# right_shoulder-right_elbow: Correct Relative Position: 55.50%, Correct Relative Depth: 68.72%
# right_elbow-right_wrist: Correct Relative Position: 50.18%, Correct Relative Depth: 62.71%
# left_shoulder-left_elbow: Correct Relative Position: 52.39%, Correct Relative Depth: 70.22%
# left_elbow-left_wrist: Correct Relative Position: 38.97%, Correct Relative Depth: 58.09%
# right_hip-right_knee: Correct Relative Position: 60.43%, Correct Relative Depth: 69.43%
# right_knee-right_ankle: Correct Relative Position: 45.51%, Correct Relative Depth: 75.06%
# left_hip-left_knee: Correct Relative Position: 58.02%, Correct Relative Depth: 68.84%
# left_knee-left_ankle: Correct Relative Position: 58.67%, Correct Relative Depth: 77.54%
# nose-right_eye: Correct Relative Position: 62.96%, Correct Relative Depth: 73.34%
# right_eye-right_ear: Correct Relative Position: 59.67%, Correct Relative Depth: 68.70%
# nose-left_eye: Correct Relative Position: 52.65%, Correct Relative Depth: 71.08%
# left_eye-left_ear: Correct Relative Position: 61.50%, Correct Relative Depth: 76.40%
# hip_center-left_hip: Correct Relative Position: 55.39%, Correct Relative Depth: 82.38%
# hip_center-right_hip: Correct Relative Position: 48.32%, Correct Relative Depth: 67.56%
# hip_center-spine_center: Correct Relative Position: 54.68%, Correct Relative Depth: 73.10%
# spine_center-neck: Correct Relative Position: 55.97%, Correct Relative Depth: 83.06%
# neck-head_lower: Correct Relative Position: 38.44%, Correct Relative Depth: 81.59%
# head_lower-head_upper: Correct Relative Position: 41.58%, Correct Relative Depth: 81.12%
# neck-left_shoulder: Correct Relative Position: 46.02%, Correct Relative Depth: 79.26%
# neck-right_shoulder: Correct Relative Position: 53.61%, Correct Relative Depth: 83.50%
# head_lower-nose: Correct Relative Position: 66.00%, Correct Relative Depth: 85.55%
# left_ankle-left_foot_end: Correct Relative Position: 40.92%, Correct Relative Depth: 79.18%
# right_ankle-right_foot_end: Correct Relative Position: 58.35%, Correct Relative Depth: 87.23%
# left_wrist-left_hand_end: Correct Relative Position: 58.59%, Correct Relative Depth: 85.60%
# right_wrist-right_hand_end: Correct Relative Position: 51.53%, Correct Relative Depth: 84.72%
# Full mean: 105.21mm | Correct Depth (Mean) 76.02% | Correct Joint Position (Mean): 53.42%

# %%
sizes = df["size"].to_numpy()
print_pose3d_results(skeleton3ds[sizes == 2], skeleton3ds_pred[sizes == 2], f"[sizes == 2]")
# Out:
# ########################################################
# #################### MPJPE: [sizes == 2], Num samples: 72157
# ########################################################
# nose: MPJPE: 88.4mm | Depth distance: 65.1mm | X distance: 30.3mm | Y distance: 31.046391mm |
# left_eye: MPJPE: 86.7mm | Depth distance: 64.7mm | X distance: 27.8mm | Y distance: 30.403709mm |
# right_eye: MPJPE: 88.2mm | Depth distance: 65.6mm | X distance: 29.1mm | Y distance: 30.512163mm |
# left_ear: MPJPE: 85.9mm | Depth distance: 64.1mm | X distance: 29.6mm | Y distance: 26.160299mm |
# right_ear: MPJPE: 90.3mm | Depth distance: 67.1mm | X distance: 31.0mm | Y distance: 27.644732mm |
# left_shoulder: MPJPE: 94.4mm | Depth distance: 67.1mm | X distance: 37.3mm | Y distance: 27.425426mm |
# right_shoulder: MPJPE: 87.3mm | Depth distance: 59.9mm | X distance: 35.7mm | Y distance: 28.445162mm |
# left_elbow: MPJPE: 104.7mm | Depth distance: 73.0mm | X distance: 44.0mm | Y distance: 32.137718mm |
# right_elbow: MPJPE: 119.5mm | Depth distance: 79.6mm | X distance: 52.8mm | Y distance: 38.757725mm |
# left_wrist: MPJPE: 150.2mm | Depth distance: 102.6mm | X distance: 61.5mm | Y distance: 53.221523mm |
# right_wrist: MPJPE: 184.7mm | Depth distance: 117.2mm | X distance: 77.2mm | Y distance: 75.417831mm |
# left_hip: MPJPE: 25.5mm | Depth distance: 16.0mm | X distance: 13.1mm | Y distance: 6.301609mm |
# right_hip: MPJPE: 25.5mm | Depth distance: 15.9mm | X distance: 13.4mm | Y distance: 6.147031mm |
# left_knee: MPJPE: 105.8mm | Depth distance: 60.0mm | X distance: 32.3mm | Y distance: 57.868156mm |
# right_knee: MPJPE: 94.7mm | Depth distance: 47.5mm | X distance: 30.4mm | Y distance: 55.524994mm |
# left_ankle: MPJPE: 168.9mm | Depth distance: 103.2mm | X distance: 48.3mm | Y distance: 86.417542mm |
# right_ankle: MPJPE: 158.2mm | Depth distance: 92.6mm | X distance: 44.5mm | Y distance: 85.143242mm |
# hip_center: MPJPE: 0.1mm | Depth distance: 0.1mm | X distance: 0.0mm | Y distance: 0.000104mm |
# spine_center: MPJPE: 37.3mm | Depth distance: 26.2mm | X distance: 13.0mm | Y distance: 14.224048mm |
# neck: MPJPE: 70.6mm | Depth distance: 51.8mm | X distance: 22.9mm | Y distance: 24.848099mm |
# head_lower: MPJPE: 79.1mm | Depth distance: 58.6mm | X distance: 24.8mm | Y distance: 27.908436mm |
# head_upper: MPJPE: 95.6mm | Depth distance: 72.5mm | X distance: 32.0mm | Y distance: 28.739336mm |
# left_foot_end: MPJPE: 184.1mm | Depth distance: 107.1mm | X distance: 60.1mm | Y distance: 91.488213mm |
# right_foot_end: MPJPE: 178.1mm | Depth distance: 99.7mm | X distance: 62.0mm | Y distance: 88.170418mm |
# left_hand_end: MPJPE: 192.6mm | Depth distance: 125.4mm | X distance: 77.1mm | Y distance: 78.939041mm |
# right_hand_end: MPJPE: 235.1mm | Depth distance: 141.2mm | X distance: 96.1mm | Y distance: 108.791153mm |
# right_shoulder-right_elbow: Correct Relative Position: 52.14%, Correct Relative Depth: 69.36%
# right_elbow-right_wrist: Correct Relative Position: 50.85%, Correct Relative Depth: 68.64%
# left_shoulder-left_elbow: Correct Relative Position: 60.61%, Correct Relative Depth: 81.28%
# left_elbow-left_wrist: Correct Relative Position: 46.94%, Correct Relative Depth: 61.34%
# right_hip-right_knee: Correct Relative Position: 58.93%, Correct Relative Depth: 69.20%
# right_knee-right_ankle: Correct Relative Position: 55.22%, Correct Relative Depth: 84.05%
# left_hip-left_knee: Correct Relative Position: 65.51%, Correct Relative Depth: 74.00%
# left_knee-left_ankle: Correct Relative Position: 60.18%, Correct Relative Depth: 84.74%
# nose-right_eye: Correct Relative Position: 71.94%, Correct Relative Depth: 78.35%
# right_eye-right_ear: Correct Relative Position: 67.28%, Correct Relative Depth: 75.20%
# nose-left_eye: Correct Relative Position: 49.09%, Correct Relative Depth: 65.15%
# left_eye-left_ear: Correct Relative Position: 62.70%, Correct Relative Depth: 77.23%
# hip_center-left_hip: Correct Relative Position: 64.97%, Correct Relative Depth: 88.13%
# hip_center-right_hip: Correct Relative Position: 56.92%, Correct Relative Depth: 70.75%
# hip_center-spine_center: Correct Relative Position: 59.96%, Correct Relative Depth: 76.51%
# spine_center-neck: Correct Relative Position: 58.21%, Correct Relative Depth: 88.25%
# neck-head_lower: Correct Relative Position: 41.58%, Correct Relative Depth: 77.99%
# head_lower-head_upper: Correct Relative Position: 39.99%, Correct Relative Depth: 77.10%
# neck-left_shoulder: Correct Relative Position: 47.34%, Correct Relative Depth: 75.86%
# neck-right_shoulder: Correct Relative Position: 55.71%, Correct Relative Depth: 82.56%
# head_lower-nose: Correct Relative Position: 59.48%, Correct Relative Depth: 83.73%
# left_ankle-left_foot_end: Correct Relative Position: 43.28%, Correct Relative Depth: 76.56%
# right_ankle-right_foot_end: Correct Relative Position: 60.59%, Correct Relative Depth: 86.70%
# left_wrist-left_hand_end: Correct Relative Position: 59.75%, Correct Relative Depth: 85.27%
# right_wrist-right_hand_end: Correct Relative Position: 52.55%, Correct Relative Depth: 84.85%
# Full mean: 108.90mm | Correct Depth (Mean) 77.72% | Correct Joint Position (Mean): 56.05%
